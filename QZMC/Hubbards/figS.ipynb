# %%
import numpy as np

# %%
data_dir = './'
additional_data_dir = '../Compare'

# %%
# read 6x1
t_6x1 = []
E_6x1 = []
norm_6x1 = []
with open(data_dir + '/Chain/6x1/E.qzmc.save','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_6x1.append(float(ls[0]))
        E_6x1.append(float(ls[1]))
        norm_6x1.append(float(ls[2]))

norm_exact_6x1 = []
with open(data_dir + '/Chain/6x1/E.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_exact_6x1.append(float(ls[2]))

t_exact_6x1 = []
E_exact_6x1 = []

with open(data_dir + '/Chain/6x1/E.exact.fine','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_exact_6x1.append(float(ls[0]))
        E_exact_6x1.append(float(ls[1]))

oml_6x1 = []
A_6x1 = []
with open(data_dir + '/Chain/6x1/A.qzmc','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_6x1.append(float(ls[0]))
        A_6x1.append(float(ls[1]))

oml_exact_6x1 = []
A_exact_6x1 = []
with open(data_dir + '/Chain/6x1/A.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_exact_6x1.append(float(ls[0]))
        A_exact_6x1.append(float(ls[1]))


# read 8x1
t_8x1 = []
E_8x1 = []
norm_8x1 = []
with open(data_dir + '/Chain/8x1/E.qzmc.save','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_8x1.append(float(ls[0]))
        E_8x1.append(float(ls[1]))
        norm_8x1.append(float(ls[2]))

norm_exact_8x1 = []
with open(data_dir + '/Chain/8x1/E.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_exact_8x1.append(float(ls[2]))


t_exact_8x1 = []
E_exact_8x1 = []

with open(data_dir + '/Chain/8x1/E.exact.fine','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_exact_8x1.append(float(ls[0]))
        E_exact_8x1.append(float(ls[1]))

oml_8x1 = []
A_8x1 = []
with open(data_dir + '/Chain/8x1/A.qzmc','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_8x1.append(float(ls[0]))
        A_8x1.append(float(ls[1]))

oml_exact_8x1 = []
A_exact_8x1 = []
with open(data_dir + '/Chain/8x1/A.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_exact_8x1.append(float(ls[0]))
        A_exact_8x1.append(float(ls[1]))


# read 10x1
t_10x1 = []
E_10x1 = []
norm_10x1 = []
with open(data_dir + '/Chain/10x1/E.qzmc.save','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_10x1.append(float(ls[0]))
        E_10x1.append(float(ls[1]))
        norm_10x1.append(float(ls[2]))

norm_exact_10x1 = []
with open(data_dir + '/Chain/10x1/E.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_exact_10x1.append(float(ls[2]))

t_exact_10x1 = []
E_exact_10x1 = []

with open(data_dir+'/Chain/10x1/E.exact.fine','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_exact_10x1.append(float(ls[0]))
        E_exact_10x1.append(float(ls[1]))

oml_10x1 = []
A_10x1 = []
with open(data_dir + '/Chain/10x1/A.qzmc','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_10x1.append(float(ls[0]))
        A_10x1.append(float(ls[1]))

oml_exact_10x1 = []
A_exact_10x1 = []
with open(data_dir + '/Chain/10x1/A.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_exact_10x1.append(float(ls[0]))
        A_exact_10x1.append(float(ls[1]))

# %%
# read ladders
# read 2x3
t_2x3 = []
E_2x3 = []
norm_2x3 = []
with open(data_dir + '/Ladder/2x3/E.qzmc.save','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_2x3.append(float(ls[0]))
        E_2x3.append(float(ls[1]))
        norm_2x3.append(float(ls[2]))

norm_exact_2x3 = []
with open(data_dir + '/Ladder/2x3/E.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_exact_2x3.append(float(ls[2]))

t_exact_2x3 = []
E_exact_2x3 = []

with open(data_dir + '/Ladder/2x3/E.exact.fine','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_exact_2x3.append(float(ls[0]))
        E_exact_2x3.append(float(ls[1]))

oml_2x3 = []
A_2x3 = []
with open(data_dir + '/Ladder/2x3/A.qzmc','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_2x3.append(float(ls[0]))
        A_2x3.append(float(ls[1]))

oml_exact_2x3 = []
A_exact_2x3 = []
with open(data_dir + '/Ladder/2x3/A.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_exact_2x3.append(float(ls[0]))
        A_exact_2x3.append(float(ls[1]))


# read 2x4
t_2x4 = []
E_2x4 = []
norm_2x4 = []
with open(data_dir + '/Ladder/2x4/E.qzmc.save','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_2x4.append(float(ls[0]))
        E_2x4.append(float(ls[1]))
        norm_2x4.append(float(ls[2]))

norm_exact_2x4 = []
with open(data_dir + '/Ladder/2x4/E.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_exact_2x4.append(float(ls[2]))

t_exact_2x4 = []
E_exact_2x4 = []

with open(data_dir + '/Ladder/2x4/E.exact.fine','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_exact_2x4.append(float(ls[0]))
        E_exact_2x4.append(float(ls[1]))

oml_2x4 = []
A_2x4 = []
with open(data_dir + '/Ladder/2x4/A.qzmc','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_2x4.append(float(ls[0]))
        A_2x4.append(float(ls[1]))

oml_exact_2x4 = []
A_exact_2x4 = []
with open(data_dir + '/Ladder/2x4/A.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_exact_2x4.append(float(ls[0]))
        A_exact_2x4.append(float(ls[1]))

# read 2x5
t_2x5 = []
E_2x5 = []
norm_2x5 = []
with open(data_dir + '/Ladder/2x5/E.qzmc.save','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_2x5.append(float(ls[0]))
        E_2x5.append(float(ls[1]))
        norm_2x5.append(float(ls[2]))

norm_exact_2x5 = []
with open(data_dir + '/Ladder/2x5/E.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_exact_2x5.append(float(ls[2]))

t_exact_2x5 = []
E_exact_2x5 = []

with open(data_dir + '/Ladder/2x5/E.exact.fine','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        t_exact_2x5.append(float(ls[0]))
        E_exact_2x5.append(float(ls[1]))

oml_2x5 = []
A_2x5 = []
with open(data_dir + '/Ladder/2x5/A.qzmc','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_2x5.append(float(ls[0]))
        A_2x5.append(float(ls[1]))

oml_exact_2x5 = []
A_exact_2x5 = []
with open(data_dir + '/Ladder/2x5/A.exact','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        oml_exact_2x5.append(float(ls[0]))
        A_exact_2x5.append(float(ls[1]))

# %%
# read additional data
norm_6x1_from_exact = []
with open(additional_data_dir + '/Chain/6x1/qzmc_with_exact_evolution','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_6x1_from_exact.append(float(ls[1]))

norm_8x1_from_exact = []
with open(additional_data_dir + '/Chain/8x1/qzmc_with_exact_evolution','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_8x1_from_exact.append(float(ls[1]))
norm_10x1_from_exact = []
with open(additional_data_dir + '/Chain/10x1/qzmc_with_exact_evolution','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_10x1_from_exact.append(float(ls[1]))

norm_2x3_from_exact = []
with open(additional_data_dir + '/2x3/qzmc_with_exact_evolution','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_2x3_from_exact.append(float(ls[1]))

norm_2x4_from_exact = []
with open(additional_data_dir + '/2x4/qzmc_with_exact_evolution','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_2x4_from_exact.append(float(ls[1]))

norm_2x5_from_exact = []
with open(additional_data_dir + '/2x5/qzmc_with_exact_evolution','r') as file_:
    for line in file_:
        if not line.strip():
            continue
        if line.startswith('#'):
            continue
        ls = line.split()
        norm_2x5_from_exact.append(float(ls[1]))

# %%
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('pdf','svg')
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica",
    "font.size"  : 7
})

cm    = 1.0/2.54
width_col = 8.6*cm
width = width_col*2 
height = width_col
plt.figure(figsize=(width,height),dpi=600)

marker_style_ref = dict(marker='',linestyle='dashed',color='black')
marker_style_ref_1 = dict(marker='',linestyle='dashed',color='tab:red', alpha=0.7)
marker_style_ref_2 = dict(marker='',linestyle='dashed',color='mediumblue',alpha=0.7)
marker_style_0  = dict(marker='s', linestyle='none', color='black', alpha=0.4,  fillstyle='none')
marker_style_1  = dict(marker='s', linestyle='none', color='tab:red', alpha=0.4,  fillstyle='full')

marker_style_2  = dict(marker='s', linestyle='none', color='mediumblue', alpha=0.4,  fillstyle='full')

marker_style_3  = dict(marker='', linestyle='-', color='tab:red', alpha=0.5,  fillstyle='full')

marker_style_4  = dict(marker='', linestyle='-', color='mediumblue', alpha=0.5,  fillstyle='full')

axes = []

ax = plt.subplot2grid((2,4),(0,0))
axes.append(ax)
ax = plt.subplot2grid((2,4),(1,0),sharex=axes[0])
axes.append(ax)
ax = plt.subplot2grid((2,4),(0,1))
axes.append(ax)
ax = plt.subplot2grid((2,4),(1,1),sharex=axes[2])
axes.append(ax)
ax = plt.subplot2grid((2,4),(0,2))
axes.append(ax)
ax = plt.subplot2grid((2,4),(1,2),sharex=axes[4])
axes.append(ax)
ax = plt.subplot2grid((2,4),(0,3))
axes.append(ax)
ax = plt.subplot2grid((2,4),(1,3),sharex=axes[6])
axes.append(ax)

# (a) norms, 6x1

axis = axes[0]

y_min    = 0.0
y_max    = 1.05

x_min    =  -0.05
x_max    =  1.05

axis.set_xlim(x_min,x_max)
axis.set_ylim(y_min,y_max)
# setup labels
axis.text(-0.29,0.95,r'(a)',transform=axis.transAxes)
axis.set_ylabel(r'$\langle\Psi|\Psi\rangle$')
axis.text(0.3,0.6,r'$6\times1$',transform=axis.transAxes)
# setup tics
axis.tick_params(axis='x', which='both', direction='in')
axis.tick_params(axis='y', which='both', direction='in')
axis.xaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.xaxis.set_major_formatter('{x:0.1f}')
axis.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))

axis.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.yaxis.set_major_formatter('{x:0.1f}')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))

# plot
##axes[0].plot(t_exact_2x3, E_exact_2x3, label='', **marker_style_ref)
##axes[0].plot(t_2x3,E_2x3, label='', markersize=4, **marker_style_1)
axis.plot(t_6x1,norm_exact_6x1, label='exact', lw=1,**marker_style_ref)
axis.plot(t_6x1,norm_6x1_from_exact, label='QZMC w/o trotter', markersize=3, **marker_style_0)
axis.plot(t_6x1,norm_6x1, label ='QZMC w/ trotter', markersize=4, **marker_style_1)


axis.legend(loc='lower right', handlelength=1.2)

plt.setp(axis.get_xticklabels(), visible=False)

# (b) norms, 2x3

axis = axes[1]

y_min    = 0.0
y_max    = 1.05

x_min    =  -0.05
x_max    =  1.05

axis.set_xlim(x_min,x_max)
axis.set_ylim(y_min,y_max)
# setup labels
axis.text(-0.29,0.95,r'(b)',transform=axis.transAxes)
axis.set_xlabel(r'$t_{\textrm{inter}}/t$')
axis.set_ylabel(r'$\langle\Psi|\Psi\rangle$')
axis.text(0.3,0.6,r'$2\times3$',transform=axis.transAxes)
# setup tics
axis.tick_params(axis='x', which='both', direction='in')
axis.tick_params(axis='y', which='both', direction='in')
axis.xaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.xaxis.set_major_formatter('{x:0.1f}')
axis.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))

axis.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.yaxis.set_major_formatter('{x:0.1f}')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))

# plot
##axes[0].plot(t_exact_2x3, E_exact_2x3, label='', **marker_style_ref)
##axes[0].plot(t_2x3,E_2x3, label='', markersize=4, **marker_style_1)
axis.plot(t_2x3,norm_exact_2x3, label='exact', lw=1,**marker_style_ref)
axis.plot(t_2x3,norm_2x3_from_exact, label='QZMC w/o trotter', markersize=3, **marker_style_0)
axis.plot(t_2x3,norm_2x3, label ='QZMC w/ trotter', markersize=4, **marker_style_2)


axis.legend(loc='lower right', handlelength=1.2)

# (c) norms, 6x1

axis = axes[2]

y_min    = 0.0
y_max    = 1.05

x_min    =  -0.05
x_max    =  1.05

axis.set_xlim(x_min,x_max)
axis.set_ylim(y_min,y_max)
# setup labels
axis.text(-0.29,0.95,r'(c)',transform=axis.transAxes)
axis.set_ylabel(r'$\langle\Psi|\Psi\rangle$')
axis.text(0.3,0.6,r'$8\times1$',transform=axis.transAxes)
# setup tics
axis.tick_params(axis='x', which='both', direction='in')
axis.tick_params(axis='y', which='both', direction='in')
axis.xaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.xaxis.set_major_formatter('{x:0.1f}')
axis.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))

axis.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.yaxis.set_major_formatter('{x:0.1f}')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))

# plot
##axes[0].plot(t_exact_2x3, E_exact_2x3, label='', **marker_style_ref)
##axes[0].plot(t_2x3,E_2x3, label='', markersize=4, **marker_style_1)
axis.plot(t_8x1,norm_exact_8x1, label='exact', lw=1,**marker_style_ref)
axis.plot(t_8x1,norm_8x1_from_exact, label='QZMC w/o trotter', markersize=3, **marker_style_0)
axis.plot(t_8x1,norm_8x1, label ='QZMC w/ trotter', markersize=4, **marker_style_1)


axis.legend(loc='lower right', handlelength=1.2)

plt.setp(axis.get_xticklabels(), visible=False)

# (d) norms, 2x3

axis = axes[3]

y_min    = 0.0
y_max    = 1.05

x_min    =  -0.05
x_max    =  1.05

axis.set_xlim(x_min,x_max)
axis.set_ylim(y_min,y_max)
# setup labels
axis.text(-0.29,0.95,r'(d)',transform=axis.transAxes)
axis.set_xlabel(r'$t_{\textrm{inter}}/t$')
axis.set_ylabel(r'$\langle\Psi|\Psi\rangle$')
axis.text(0.3,0.6,r'$2\times4$',transform=axis.transAxes)
# setup tics
axis.tick_params(axis='x', which='both', direction='in')
axis.tick_params(axis='y', which='both', direction='in')
axis.xaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.xaxis.set_major_formatter('{x:0.1f}')
axis.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))

axis.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.yaxis.set_major_formatter('{x:0.1f}')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))

# plot
##axes[0].plot(t_exact_2x3, E_exact_2x3, label='', **marker_style_ref)
##axes[0].plot(t_2x3,E_2x3, label='', markersize=4, **marker_style_1)
axis.plot(t_2x4,norm_exact_2x4, label='exact', lw=1,**marker_style_ref)
axis.plot(t_2x4,norm_2x4_from_exact, label='QZMC w/o trotter', markersize=3, **marker_style_0)
axis.plot(t_2x4,norm_2x4, label ='QZMC w/ trotter', markersize=4, **marker_style_2)


axis.legend(loc='lower right', handlelength=1.2)

# (e) norms, 10x1

axis = axes[4]

y_min    = 0.0
y_max    = 1.05

x_min    =  -0.05
x_max    =  1.05

axis.set_xlim(x_min,x_max)
axis.set_ylim(y_min,y_max)
# setup labels
axis.text(-0.29,0.95,r'(e)',transform=axis.transAxes)
axis.set_ylabel(r'$\langle\Psi|\Psi\rangle$')
axis.text(0.3,0.6,r'$10\times1$',transform=axis.transAxes)
# setup tics
axis.tick_params(axis='x', which='both', direction='in')
axis.tick_params(axis='y', which='both', direction='in')
axis.xaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.xaxis.set_major_formatter('{x:0.1f}')
axis.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))

axis.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.yaxis.set_major_formatter('{x:0.1f}')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))

# plot
##axes[0].plot(t_exact_2x3, E_exact_2x3, label='', **marker_style_ref)
##axes[0].plot(t_2x3,E_2x3, label='', markersize=4, **marker_style_1)
axis.plot(t_10x1,norm_exact_10x1, label='exact', lw=1,**marker_style_ref)
axis.plot(t_10x1,norm_10x1_from_exact, label='QZMC w/o trotter', markersize=3, **marker_style_0)
axis.plot(t_10x1,norm_10x1, label ='QZMC w/ trotter', markersize=4, **marker_style_1)


axis.legend(loc='lower right', handlelength=1.2)

plt.setp(axis.get_xticklabels(), visible=False)

# (f) norms, 2x5

axis = axes[5]

y_min    = 0.0
y_max    = 1.05

x_min    =  -0.05
x_max    =  1.05

axis.set_xlim(x_min,x_max)
axis.set_ylim(y_min,y_max)
# setup labels
axis.text(-0.29,0.95,r'(f)',transform=axis.transAxes)
axis.set_xlabel(r'$t_{\textrm{inter}}/t$')
axis.set_ylabel(r'$\langle\Psi|\Psi\rangle$')
axis.text(0.3,0.6,r'$2\times5$',transform=axis.transAxes)
# setup tics
axis.tick_params(axis='x', which='both', direction='in')
axis.tick_params(axis='y', which='both', direction='in')
axis.xaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.xaxis.set_major_formatter('{x:0.1f}')
axis.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))

axis.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
axis.yaxis.set_major_formatter('{x:0.1f}')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))

# plot
##axes[0].plot(t_exact_2x3, E_exact_2x3, label='', **marker_style_ref)
##axes[0].plot(t_2x3,E_2x3, label='', markersize=4, **marker_style_1)
axis.plot(t_2x5,norm_exact_2x5, label='exact', lw=1,**marker_style_ref)
axis.plot(t_2x5,norm_2x5_from_exact, label='QZMC w/o trotter', markersize=3, **marker_style_0)
axis.plot(t_2x5,norm_2x5, label ='QZMC w/ trotter', markersize=4, **marker_style_2)

axis.legend(loc='lower right',handlelength=1.2)




# (g) A, 6x1

axis = axes[6]

y_min    =  -0.05
y_max    =  0.55
#
x_min    =  -8
x_max    =  8

axis.set_xlim(x_min,x_max)
axis.set_ylim(y_min,y_max)
# setup labels
axis.text(-0.29,0.95,r'(g)',transform=axis.transAxes)
axis.set_xlabel(r'$\omega/t$')
axis.set_ylabel(r'$A(\omega)$')
#axis.text(0.5,-0.2,r'$\omega/t$',transform=axis.transAxes)
#axis.text(-0.28,0.5,r'$A(\omega)$',transform=axis.transAxes)
axis.text(0.15,0.8,r'$6\times1$',transform=axis.transAxes)
# setup tics
axis.tick_params(axis='x', which='both', direction='in')
axis.tick_params(axis='y', which='both', direction='in')
axis.xaxis.set_major_locator(ticker.MultipleLocator(3))
axis.xaxis.set_major_formatter('{x:0.1f}')
axis.xaxis.set_minor_locator(ticker.MultipleLocator(1.5))

axis.yaxis.set_major_locator(ticker.MultipleLocator(0.1))
axis.yaxis.set_major_formatter('{x:0.1f}')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(0.05))

# plot
axis.plot(oml_exact_6x1,A_exact_6x1, label='exact', lw=1, **marker_style_ref)

axis.plot(oml_6x1,A_6x1, label ='QZMC', markersize=2, lw=2, **marker_style_3)


axis.legend(loc='upper right')

plt.setp(axis.get_xticklabels(), visible=False)

# (h) A_2x3
axis = axes[7]

y_min    =  -0.05
y_max    =  0.55
#
x_min    =  -8
x_max    =  8

axis.set_xlim(x_min,x_max)
axis.set_ylim(y_min,y_max)
# setup labels
axis.text(-0.29,0.95,r'(h)',transform=axis.transAxes)
axis.set_xlabel(r'$\omega/t$')
axis.set_ylabel(r'$A(\omega)$')
#axis.text(0.5,-0.2,r'$\omega/t$',transform=axis.transAxes)
#axis.text(-0.28,0.5,r'$A(\omega)$',transform=axis.transAxes)
axis.text(0.15,0.8,r'$2\times3$',transform=axis.transAxes)
# setup tics
axis.tick_params(axis='x', which='both', direction='in')
axis.tick_params(axis='y', which='both', direction='in')
axis.xaxis.set_major_locator(ticker.MultipleLocator(3))
axis.xaxis.set_major_formatter('{x:0.1f}')
axis.xaxis.set_minor_locator(ticker.MultipleLocator(1.5))

axis.yaxis.set_major_locator(ticker.MultipleLocator(0.1))
axis.yaxis.set_major_formatter('{x:0.1f}')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(0.05))

# plot
axis.plot(oml_exact_2x3,A_exact_2x3, label='exact', lw=1, **marker_style_ref)

axis.plot(oml_2x3,A_2x3, label ='QZMC', markersize=2, lw=2, **marker_style_4)

axis.legend(loc='upper right')

#plt.setp(axis.get_xticklabels(), visible=False)





plt.tight_layout()
plt.subplots_adjust(hspace=0.05)

plt.savefig('figS10.pdf')
